# %%
# !pip install pandas openpyxl

# %%
# !pip install xlrd

# %%
import os
shark = os.listdir(r"C:\Users\Utilisateur\IronHack\Week2\Mini_Project") 
#because we are in the forlder of the file, no need to give the absolute file

# %%
import pandas as pd

# Utilisez le chemin complet et le nom du fichier comme une chaîne de caractères
file_path = r'C:\Users\Utilisateur\IronHack\Week2\Mini_Project\GSAF5.xls'
df = pd.read_excel(file_path)

# Affiche les 5 premières lignes du DataFrame pour vérifier la lecture
display(df.head())
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  ...             Species   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7050 non-null   object
#  1   Year            7048 non-null   float64
#  2   Type            7032 non-null   object
#  3   Country         7000 non-null   object
#  4   State           6564 non-null   object
#  5   Location        6483 non-null   object
#  6   Activity        6465 non-null   object
#  7   Name            6831 non-null   object
#  8   Sex             6471 non-null   object
#  9   Age             4056 non-null   object
#  10  Injury          7015 non-null   object
#  11  Fatal Y/N       6489 non-null   object
#  12  Time            3524 non-null   object
#  13  Species         3919 non-null   object
#  14  Source          7030 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
df['Activity'].isna().sum() #585 cells are empty, i suggest to avoid them beacause <<10% of 6465 of they are not relevant
# Out:
# np.int64(585)

# %%
df["Activity"].nunique() #1608 activities differentes
# Out:
# 1608

# %%
df['Activity'].value_counts().head(160)  #before more cleaning, this can show us that the mayority of the activities are in the line of code
# Out:
# Activity
# Surfing                                                                                                                                         1140
# Swimming                                                                                                                                        1005
# Fishing                                                                                                                                          493
# Spearfishing                                                                                                                                     391
# Wading                                                                                                                                           178
# Bathing                                                                                                                                          164
# ...

# %%
df['Activity'].str.contains('Swimming', case=False).sum()
# Out:
# 1266

# %%
df['Activity'].str.contains('Diving', case=False).sum()
# Out:
# 632

# %%
import re

def clean_activity(activity):
    # Check if the entry is a string
    if isinstance(activity, str):
        # Use regular expression to find the first word before any delimiters
        match = re.match(r'^([^\s\/;\-\.,]+)', activity)
        if match:
            return match.group(1)
        else:
            return activity.strip()
    else:
        return ''  # or your desired default for non-string entries

# Apply the function to the DataFrame
df['clean_activity'] = df['Activity'].apply(clean_activity)

print(df['clean_activity'].head(400))  # Print the first few entries of the new column                                                                                                                   ', case=False).sum()
# Out:
# 0            Swimming
# 1             Fishing
# 2             Surfing
# 3            Swimming
# 4              Diving
# 5             Surfing
# 6          Snorkeling
# 7            Swimming
# 8             Surfing
# 9        Spearfishing
# 10            Fishing
# 11            Surfing
# 12             Wading
# 13           Kayaking
# 14           Swimming
# 15           Swimming
# 16            Surfing
# 17             Diving
# 18            Surfing
# 19       Spearfishing
# 20            Fishing
# 21            Surfing
# 22            Fishing
# 23           Swimming
# 24           Swimming
# 25           Swimming
# 26           Swimming
# 27         Snorkeling
# 28            Surfing
# 29           Swimming
# 30           Swimming
# 31           Swimming
# 32           Paddling
# 33             Diving
# 34           Rescuing
# 35         snorkeling
# 36        Undisclosed
# 37           Swimming
# 38            Surfing
# 39           Swimming
# 40           Swimming
# ...
